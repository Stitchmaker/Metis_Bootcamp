# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

'''
divisions_2A_1 = ([[1,'91709'],  #2A Division 1
              [1,'82456'],
              [1,'73281'],
              [1,'62323'],
              [1,'52172'],
              [1,'45806'],
              [1,'34918'],
              [1,'30617'],
              [1,'19827'],
              [1,'12189']])
divisions_3A_1 = ([[1,'91728'],  #3A Division 1
              [1,'82475'],
              [1,'73299'],
              [1,'62341'],
              [1,'52190'],
              [1,'45824'],
              [1,'34936'],
              [1,'30635'],
              [1,'19845'],
              [1,'12205']])
divisions_4A_1 = ([[1,'91744'],  #4A Division 1
              [1,'82493'],
              [1,'73319'],
              [1,'62361'],
              [1,'52210'],
              [1,'45842'],
              [1,'34954'],
              [1,'30652'],
              [1,'19862'],
              [1,'12223']])

#athlete_list_url="https://www.athletic.net/TrackAndField/Division/Event.aspx?DivID=91731&Event=21"
for i in range(10):
    print(int(divisions_4A_1[i][1]) - int(divisions_3A_1[i][1]))
'''
# Out:
# '\ndivisions_2A_1 = ([[1,\'91709\'],  #2A Division 1\n              [1,\'82456\'],\n              [1,\'73281\'],\n              [1,\'62323\'],\n              [1,\'52172\'],\n              [1,\'45806\'],\n              [1,\'34918\'],\n              [1,\'30617\'],\n              [1,\'19827\'],\n              [1,\'12189\']])\ndivisions_3A_1 = ([[1,\'91728\'],  #3A Division 1\n              [1,\'82475\'],\n              [1,\'73299\'],\n              [1,\'62341\'],\n              [1,\'52190\'],\n              [1,\'45824\'],\n              [1,\'34936\'],\n              [1,\'30635\'],\n              [1,\'19845\'],\n              [1,\'12205\']])\ndivisions_4A_1 = ([[1,\'91744\'],  #4A Division 1\n              [1,\'82493\'],\n              [1,\'73319\'],\n              [1,\'62361\'],\n              [1,\'52210\'],\n              [1,\'45842\'],\n              [1,\'34954\'],\n              [1,\'30652\'],\n              [1,\'19862\'],\n              [1,\'12223\']])\n\n#athlete_list_url="https://www.athletic.net/TrackAndField/Division/Event.aspx?DivID=91731&Event=21"\nfor i in range(10):\n    print(int(divisions_4A_1[i][1]) - int(divisions_3A_1[i][1]))\n'

# %%
#Select the Event

#Event = "&Event=21" #Women's 400
Event = "&Event=3" #Men's 400

#Event = "&Event=53" #Women's 1600
#Event = "&Event=52" #Men's 1600

# %%
district_ranges = ([[12173,12236],
                   [19810,19875],
                   [30600,30666],
                   [34898,34960],
                   [45786,45857],
                   [62303,62378],
                   [73261,73336],
                   [82437,82508],
                   [91690,91760]])

district_ranges = ([[12173,12236],
                   [19810,19875],
                   [30600,30666],
                   [34898,34960],
                   [45786,45857],
                   [62303,62378]])

district_ranges = ([[73261,73336],
                   [82437,82508],
                   [91690,91760]])

district_ranges = ([[12173,12236],
                   [19810,19875],
                   [30600,30666],
                   [34898,34960],
                   [45786,45857],
                   [62303,62378],
                   [73261,73336],
                   [82437,82508],
                   [91690,91760]])


#for i in range(9):
#    print(division_ranges[i][1]-division_ranges[i][0])

# %%
# loop through the HTML pages for each district (and subdistrict) and
# pull the athlete names, school, etc.

def read_div_year(Div,Div_id,Event):
    id_key_string =     "../Athlete.aspx?AID="
    school_key_string = "../School.aspx?SchoolID="

    athlete_list_url="https://www.athletic.net/TrackAndField/Division/Event.aspx?DivID="+Div_id+Event

    response = requests.get(athlete_list_url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")
    
    cols = ['ID','Name','School_ID','School','Division']
    athlete_list = pd.DataFrame(columns=cols)

    tables=soup.find_all("table")
    
    
    for i in tables:
        for row in i:
            str_row = str(row)
            id_index = str_row.find(id_key_string)
            if id_index != -1:
    # extract the athlete ID
                str_row = str_row[id_index+20:]            
                id_str = str_row[0:8]
                id_str = id_str.replace('\"',"")
                id_str = id_str.replace('>','')
                #ID = int(id_str)
    # extract the athlete Name
                name_index = str_row.find(">") + 1
                str_row = str_row[name_index:]
                name_index = str_row.find("<")
                Name = str_row[0:name_index] # save this data
    # extract the athlete school
                school_index = str_row.find(school_key_string)
                str_row = str_row[school_index+24:]
                school_index = str_row.find('\">')
                if (Name != 'Grace Hong') & (Name != 'Cass Elliott'):
                    #print(Name,str_row[0:school_index])
                    school_id = int(str_row[0:school_index]) # save this data
                    str_row = str_row[school_index+2:]
                    school_index = str_row.find("<")
                    school_name = str_row[0:school_index] #save this data
                else:
                    school_name = 'xxx'
                    school_id = np.nan
                if id_str.isdigit():
                    ID = int(id_str)
                    athlete_list = athlete_list.append({'ID': ID, 'Name': Name, 'School_ID': school_id, 'School': school_name, 'Division': Div}, ignore_index=True)

    athlete_list = athlete_list.set_index(['ID'])
    return athlete_list

# %%
'''
# test just one district
div = 1
div_id = '82497'
new_list = read_div_year(div,div_id,Event)
'''

# %%
'''
# Loop through list of division data, extracting athlete data
all_athlete_list = pd.DataFrame()
for div, div_id in divisions_4A_1:
    new_list = read_div_year(div,div_id,Event)
    all_athlete_list = all_athlete_list.append(new_list)
'''

# %%
#loop through ranges of district data for each year
# Create a long list of athletes doing this Event
all_athlete_list = pd.DataFrame()
for dist in district_ranges:
    start = dist[0]
    end = dist[1]
    print("starting new year",start,end)

    for d in range(start,end):
        print(d)
        new_list = read_div_year(0,str(d),Event)
        all_athlete_list = all_athlete_list.append(new_list)
# Out:
# starting new year 12173 12236
# 12173
# 12174
# 12175
# 12176
# 12177
# 12178
# 12179
# 12180
# 12181
# 12182
# 12183
# 12184
# 12185
# 12186
# 12187
# 12188
# 12189
# 12190
# 12191
# 12192
# 12193
# 12194
# 12195
# 12196
# 12197
# 12198
# 12199
# 12200
# 12201
# 12202
# 12203
# 12204
# 12205
# 12206
# 12207
# 12208
# 12209
# 12210
# 12211
# 12212
# 12213
# 12214
# 12215
# 12216
# 12217
# 12218
# 12219
# 12220
# 12221
# 12222
# 12223
# 12224
# 12225
# 12226
# 12227
# 12228
# 12229
# 12230
# 12231
# 12232
# 12233
# 12234
# 12235
# starting new year 19810 19875
# 19810
# 19811
# 19812
# 19813
# 19814
# 19815
# 19816
# 19817
# 19818
# 19819
# 19820
# 19821
# 19822
# 19823
# 19824
# 19825
# 19826
# 19827
# 19828
# 19829
# 19830
# 19831
# 19832
# 19833
# 19834
# 19835
# 19836
# 19837
# 19838
# 19839
# 19840
# 19841
# 19842
# 19843
# 19844
# 19845
# 19846
# 19847
# 19848
# 19849
# 19850
# 19851
# 19852
# 19853
# 19854
# 19855
# 19856
# 19857
# 19858
# 19859
# 19860
# 19861
# 19862
# 19863
# 19864
# 19865
# 19866
# 19867
# 19868
# 19869
# 19870
# 19871
# 19872
# 19873
# 19874
# starting new year 30600 30666
# 30600
# 30601
# 30602
# 30603
# 30604
# 30605
# 30606
# 30607
# 30608
# 30609
# 30610
# 30611
# 30612
# 30613
# 30614
# 30615
# 30616
# 30617
# 30618
# 30619
# 30620
# 30621
# starting new year 82437 82508
# 82437
# 82438
# 82439
# 82440
# 82441
# 82442
# 82443
# 82444
# 82445
# 82446
# 82447
# 82448
# 82449
# 82450
# 82451
# 82452
# 82453
# 82454
# 82455
# 82456
# 82457
# 82458
# 82459
# 82460
# 82461
# 82462
# 82463
# 82464
# 82465
# 82466
# 82467
# 82468
# 82469
# 82470
# 82471
# 82472
# 82473
# 82474
# 82475
# 82476
# 82477
# 82478
# 82479
# 82480
# 82481
# 82482
# 82483
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-1ed4297f7e17> in <module>()
#       9     for d in range(start,end):
#      10         print(d)
# ---> 11         new_list = read_div_year(0,str(d),Event)
#      12         all_athlete_list = all_athlete_list.append(new_list)
#
# <ipython-input-20-27b269cac0c4> in read_div_year(Div, Div_id, Event)
#      40                 if (Name != 'Grace Hong') & (Name != 'Cass Elliott'):
#      41                     #print(Name,str_row[0:school_index])
# ---> 42                     school_id = int(str_row[0:school_index]) # save this data
#      43                     str_row = str_row[school_index+2:]
#      44                     school_index = str_row.find("<")
#
# ValueError: invalid literal for int() with base 10: 'd class="text-nowrap hidden-print'

# %%
# remove duplicate athletes in the list
all_athlete_list.drop_duplicates(inplace=True)
all_athlete_list.shape
# Out:
# (11696, 4)

# %%
all_athlete_list.head()
# Out:
#                  Name School_ID              School Division
# ID
# 1671873   Josh Fuller       345              King's        0
# 146314      Ben Allen       382            Cashmere        0
# 1817645    Kyle Fremd       301  Bellevue Christian        0
# 334397   Frank Krause       315            Onalaska        0
# 285695   Scott Eberle       341             Freeman        0

# %% [markdown]
# Correlate the district number to the athlete

# %%
# read file with schools for each district
district_list = pd.read_csv('WA_athletic_districts1.csv')

all_athlete_list['District'] = np.nan
for index, athlete in all_athlete_list.iterrows():
    School = athlete['School']
    
    for district in district_list: 
        for item in district_list[district]:
            if item == School:
#                print("found it",School,district)
                all_athlete_list.District[index] = district
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# How many unique schools are on the list
print("number of athletes ",all_athlete_list.shape)
print("Unique Schools ",all_athlete_list['School'].drop_duplicates().shape)
# Out:
# number of athletes  (11696, 5)
# Unique Schools  (284,)

# %%
# Remove rows with incomplete school information
print("number of athletes before removing incompletes ",all_athlete_list.shape)
print("number of athletes after removing incompletes ",all_athlete_list.dropna().shape)

all_athlete_list.dropna(inplace=True)
# Out:
# number of athletes before removing incompletes  (11696, 5)
# number of athletes after removing incompletes  (8718, 5)

# %%
# write to file
all_athlete_list.to_csv('athlete_list_boy400.csv')

# %%
all_athlete_list
# Out:
#                           Name School_ID                 School Division  \
# ID
# 4874126          Maddie Meyers       306              Northwest        0
# 1675244          Olivia Thomas       345                 King's        0
# 185032           Chanda Romney       364                  Forks        0
# 133607           Anne de Vries       308        University Prep        0
# 120359          Allison Hussey       301     Bellevue Christian        0
# 178463        Gabriela Guillen       383                 Chelan        0
# 172639         Meagan Governor       369              La Center        0
# 131366          Sammy Sullivan       371              Stevenson        0
# 330317         Melissa Gibbons       374                Connell        0
# 237711           Jessica Spear       338               Tonasket        0
# 531401               Kim Barry       334         Lake Roosevelt        0
# 235162      Amanda Blankenship       369              La Center        0
# 266727          Kayleigh McCoy       357                 Orting        0
# 114724           Shayla Maupin       309        Seattle Academy        0
# 237016           Savannah Krug       360          Vashon Island        0
# 823099        Liz Webber-Bruya       306              Northwest        0
# 518384          Hailey Ziegler       381  Cascade (Leavenworth)        0
# 555801        Allison Peterson       366              Montesano        0
