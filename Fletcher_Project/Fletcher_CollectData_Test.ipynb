# %%
from nytimesarticle import articleAPI
api = articleAPI('6a6c043c723548a98eafc5b624317cac')
key = 6a6c043c723548a98eafc5b624317cac

# %%
articles = api.search( q = 'terrorist attack')

print(articles['response'],['docs'],['web_url'])
# Out:
# {'docs': [{'web_url': 'https://www.nytimes.com/2018/09/28/world/europe/netherlands-terrorist-attack-arrests.html', 'snippet': 'A police operation across several towns and cities yielded powerful guns and bomb-making materials.', 'print_page': '12', 'blog': {}, 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/29/world/29netherlands-1-print/merlin_144441402_073d7b3b-9fdd-448f-b4dd-f0e250dfbc1e-articleLarge.jpg', 'height': 400, 'width': 600, 'legacy': {'xlarge': 'images/2018/09/29/world/29netherlands-1-print/merlin_144441402_073d7b3b-9fdd-448f-b4dd-f0e250dfbc1e-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 400}, 'subType': 'xlarge', 'crop_name': 'articleLarge'}, {'rank': 0, 'subtype': 'wide', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/29/world/29netherlands-1-print/merlin_144441402_073d7b3b-9fdd-448f-b4dd-f0e250dfbc1e-thumbWide.jpg', 'height': 126, 'width': 190, 'legacy': {'wide': 'images/2018/09/29/world/29netherlands-1-print/merlin_144441402_073d7b3b-9fdd-448f-b4dd-f0e250dfbc1e-thumbWide.jpg', 'widewidth': 190, 'wideheight': 126}, 'subType': 'wide', 'crop_name': 'thumbWide'}, {'rank': 0, 'subtype': 'thumbnail', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/29/world/29netherlands-1-print/29netherlands-thumbStandard.jpg', 'height': 75, 'width': 75, 'legacy': {'thumbnail': 'images/2018/09/29/world/29netherlands-1-print/29netherlands-thumbStandard.jpg', 'thumbnailwidth': 75, 'thumbnailheight': 75}, 'subType': 'thumbnail', 'crop_name': 'thumbStandard'}, {'rank': 0, 'subtype': 'articleInline', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/29/world/29netherlands-1-print/merlin_144441402_073d7b3b-9fdd-448f-b4dd-f0e250dfbc1e-articleInline.jpg', 'height': 127, 'width': 190, 'legacy': {}, 'subType': 'articleInline', 'crop_name': 'articleInline'}, {'rank': 0, 'subtype': 'blog225', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/29/world/29netherlands-1-print/merlin_144441402_073d7b3b-9fdd-448f-b4dd-f0e250dfbc1e-blog225.jpg', 'height': 150, 'width': 225, 'legacy': {}, 'subType': 'blog225', 'crop_name': 'blog225'}, {'rank': 0, 'subtype': 'blog427', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/29/world/29netherlands-1-print/merlin_144441402_073d7b3b-9fdd-448f-b4dd-f0e250dfbc1e-blog427.jpg', 'height': 285, 'width': 427, 'legacy': {}, 'subType': 'blog427', 'crop_name': 'blog427'}, {'rank': 0, 'subtype': 'blog480', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/29/world/29netherlands-1-print/merlin_144441402_073d7b3b-9fdd-448f-b4dd-f0e250dfbc1e-blog480.jpg', 'height': 320, 'width': 480, 'legacy': {}, 'subType': 'blog480', 'crop_name': 'blog480'}, {'rank': 0, 'subtype': 'blog533', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/29/world/29netherlands-1-print/merlin_144441402_073d7b3b-9fdd-448f-b4dd-f0e250dfbc1e-blog533.jpg', 'height': 355, 'width': 533, 'legacy': {}, 'subType': 'blog533', 'crop_name': 'blog533'}, {'rank': 0, 'subtype': 'blogSmallInline', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/29/world/29netherlands-1-print/merlin_144441402_073d7b3b-9fdd-448f-b4dd-f0e250dfbc1e-blogSmallInline.jpg', 'height': 101, 'width': 151, 'legacy': {}, 'subType': 'blogSmallInline', 'crop_name': 'blogSmallInline'}, {'rank': 0, 'subtype': 'blogSmallThumb', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/29/world/29netherlands-1-print/29netherlands-blogSmallThumb.jpg', 'height': 50, 'width': 50, 'legacy': {}, 'subType': 'blogSmallThumb', 'crop_name': 'blogSmallThumb'}, {'rank': 0, 'subtype': 'facebookJumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/29/world/29netherlands-1-print/29netherlands-facebookJumbo.jpg', 'height': 550, 'width': 1050, 'legacy': {}, 'subType': 'facebookJu ...

# %%
articles = api.search( q = 'Obama', 
     fq = {'headline':'Obama', 'source':['Reuters','AP', 'The New York Times']}, 
     begin_date = 20111231 )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-0d800a95b02c> in <module>()
#       1 articles = api.search( q = 'Obama',
#       2      fq = {'headline':'Obama', 'source':['Reuters','AP', 'The New York Times']},
# ----> 3      begin_date = 20111231 )
#
# /anaconda3/lib/python3.6/site-packages/nytimesarticle.py in search(self, response_format, key, **kwargs)
#     109
#     110         url = '%s%s?%sapi-key=%s' % (
# --> 111             API_ROOT, response_format, self._options(**kwargs), key
#     112         )
#     113
#
# /anaconda3/lib/python3.6/site-packages/nytimesarticle.py in _options(self, **kwargs)
#      82         for k, v in kwargs.items():
#      83             if k is 'fq' and isinstance(v, dict):
# ---> 84                 v = _format_fq(v)
#      85             elif isinstance(v, list):
#      86                 v = ','.join(v)
#
# /anaconda3/lib/python3.6/site-packages/nytimesarticle.py in _format_fq(d)
#      67                     d[k] = ' '.join(map(lambda x: '"' + x + '"', v))
#      68                 else:
# ---> 69                     d[k] = '"' + v + '"'
#      70             values = []
#      71             for k,v in d.items():
#
# TypeError: must be str, not bytes

# %%
articles = api.search(q='Obama',
                          fq={'headline': 'Obama',
                              'source': ['Reuters',
                                         'AP',
                                         'The New York Times']},
                          begin_date=20161023, # this can also be an int
                          facet_field=['source', 'day_of_week'],
                          facet_filter=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-0dbe5c9e5788> in <module>()
#       6                           begin_date=20161023, # this can also be an int
#       7                           facet_field=['source', 'day_of_week'],
# ----> 8                           facet_filter=True)
#
# /anaconda3/lib/python3.6/site-packages/nytimesarticle.py in search(self, response_format, key, **kwargs)
#     109
#     110         url = '%s%s?%sapi-key=%s' % (
# --> 111             API_ROOT, response_format, self._options(**kwargs), key
#     112         )
#     113
#
# /anaconda3/lib/python3.6/site-packages/nytimesarticle.py in _options(self, **kwargs)
#      82         for k, v in kwargs.items():
#      83             if k is 'fq' and isinstance(v, dict):
# ---> 84                 v = _format_fq(v)
#      85             elif isinstance(v, list):
#      86                 v = ','.join(v)
#
# /anaconda3/lib/python3.6/site-packages/nytimesarticle.py in _format_fq(d)
#      67                     d[k] = ' '.join(map(lambda x: '"' + x + '"', v))
#      68                 else:
# ---> 69                     d[k] = '"' + v + '"'
#      70             values = []
#      71             for k,v in d.items():
#
# TypeError: must be str, not bytes

# %%
import json
import time
import pandas as pd

api = articleAPI('6a6c043c723548a98eafc5b624317cac')

data = pd.DataFrame()
for x in range(10):
#    f = api.search(q='Metis', begin_date='20000101', page=str(x))
    f = api.search(q = 'Obama',fq='Obama', begin_date=20180101)
    #print(f.keys())
    #print(f['response']['docs'])

    try:
        print('worked')
        data = data.append(f['response']['docs'])
        time.sleep(1)
    except:
        print('pass')
        pass

with open('results.json', 'w') as fp:
    json.dump(data, fp)
# Out:
# worked
# worked
# worked
# worked
# worked
# worked
# worked
# worked
# worked
# worked
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-a8777df834b2> in <module>()
#      21
#      22 with open('results.json', 'w') as fp:
# ---> 23     json.dump(data, fp)
#
# /anaconda3/lib/python3.6/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# /anaconda3/lib/python3.6/json/encoder.py in _iterencode(o, _current_indent_level)
#     435                     raise ValueError("Circular reference detected")
#     436                 markers[markerid] = o
# --> 437             o = _default(o)
#     438             yield from _iterencode(o, _current_indent_level)
#     439             if markers is not None:
#
# /anaconda3/lib/python3.6/json/encoder.py in default(self, o)
#     178         """
#     179         raise TypeError("Object of type '%s' is not JSON serializable" %
# --> 180                         o.__class__.__name__)
#     181
#     182     def encode(self, o):
#
# TypeError: Object of type 'DataFrame' is not JSON serializable

# %%
print(data)
# Out:
# None

# %%
articles = api.search(q = 'Obama',fq='Obama', begin_date=20180101)

# %%
print(articles.keys())
print(articles['response']['docs'])
# Out:
# dict_keys(['status', 'copyright', 'response'])
# [{'web_url': 'https://www.nytimes.com/2018/09/07/us/politics/obama-2018-campaign-trump.html', 'snippet': 'The former president offered a stinging indictment of his successor, sometimes by name, accusing him and his Republican supporters of practicing a “politics of fear and resentment.”', 'print_page': '1', 'blog': {}, 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-articleLarge.jpg', 'height': 400, 'width': 600, 'legacy': {'xlarge': 'images/2018/09/08/us/08obama_xp/08obama_xp-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 400}, 'subType': 'xlarge', 'crop_name': 'articleLarge'}, {'rank': 0, 'subtype': 'wide', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-thumbWide-v2.jpg', 'height': 126, 'width': 190, 'legacy': {'wide': 'images/2018/09/08/us/08obama_xp/08obama_xp-thumbWide-v2.jpg', 'widewidth': 190, 'wideheight': 126}, 'subType': 'wide', 'crop_name': 'thumbWide'}, {'rank': 0, 'subtype': 'thumbnail', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-thumbStandard.jpg', 'height': 75, 'width': 75, 'legacy': {'thumbnail': 'images/2018/09/08/us/08obama_xp/08obama_xp-thumbStandard.jpg', 'thumbnailwidth': 75, 'thumbnailheight': 75}, 'subType': 'thumbnail', 'crop_name': 'thumbStandard'}, {'rank': 0, 'subtype': 'articleInline', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-articleInline-v2.jpg', 'height': 127, 'width': 190, 'legacy': {}, 'subType': 'articleInline', 'crop_name': 'articleInline'}, {'rank': 0, 'subtype': 'blog225', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-blog225.jpg', 'height': 150, 'width': 225, 'legacy': {}, 'subType': 'blog225', 'crop_name': 'blog225'}, {'rank': 0, 'subtype': 'blog427', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-blog427.jpg', 'height': 285, 'width': 427, 'legacy': {}, 'subType': 'blog427', 'crop_name': 'blog427'}, {'rank': 0, 'subtype': 'blog480', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-blog480.jpg', 'height': 320, 'width': 480, 'legacy': {}, 'subType': 'blog480', 'crop_name': 'blog480'}, {'rank': 0, 'subtype': 'blog533', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-blog533.jpg', 'height': 355, 'width': 533, 'legacy': {}, 'subType': 'blog533', 'crop_name': 'blog533'}, {'rank': 0, 'subtype': 'blogSmallInline', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-blogSmallInline-v2.jpg', 'height': 101, 'width': 151, 'legacy': {}, 'subType': 'blogSmallInline', 'crop_name': 'blogSmallInline'}, {'rank': 0, 'subtype': 'blogSmallThumb', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-blogSmallThumb.jpg', 'height': 50, 'width': 50, 'legacy': {}, 'subType': 'blogSmallThumb', 'crop_name': 'blogSmallThumb'}, {'rank': 0, 'subtype': 'facebookJumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-facebookJumbo.jpg', 'height': 550, 'width': 1050, 'legacy': {}, 'subType': 'facebookJumbo', 'crop_name': 'facebookJumbo'}, {'rank': 0, 'subtype': 'filmstrip', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-filmstrip.jpg', 'height': 190, 'width': 190, 'legacy': {}, 'subType': 'filmstrip', 'crop_name': 'filmstrip'}, {'rank': 0, 'subtype': 'hpLarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/09/08/us/08obama_xp/08obama_xp-hpLarge.jpg', 'height': 287, 'width': 511, 'legacy': {}, 'subType': 'hpLarge', 'crop_name': 'hpLarge'}, {'rank': 0, 'subtype': 'hpSmall', 'caption' ...

# %%
parse_articles(articles)
# Out:
# [{'id': '5b92ba3e00a1bc2872e87422',
#   'headline': b'Obama Lashes Trump in Debut 2018 Speech. President\xe2\x80\x99s Response: \xe2\x80\x98I Fell Asleep.\xe2\x80\x99',
#   'desk': 'Washington',
#   'date': '2018-09-07',
#   'section': 'Politics',
#   'snippet': b'The former president offered a stinging indictment of his successor, sometimes by name, accusing him and his Republican supporters of practicing a \xe2\x80\x9cpolitics of fear and resentment.\xe2\x80\x9d',
#   'source': 'The New York Times',
#   'type': 'News',
#   'url': 'https://www.nytimes.com/2018/09/07/us/politics/obama-2018-campaign-trump.html',
#   'word_count': 1468,
#   'locations': [],
#   'subjects': ['Midterm Elections (2018)',
#    'United States Politics and Government',
#    'Speeches and Statements',
#    'Elections, House of Representatives',
#    'Elections, Senate']},
#  {'id': '5b307cf100a1bc2872e650c6',
#   'headline': b'Postcards From Another Era: Obama Team Memoirs Flood the Stores',
#   'desk': 'Washington',
#   'date': '2018-06-24',
#   'section': 'Politics',
#   'snippet': b'If it seems as if everyone who worked for former President Barack Obama has a new book out, that\xe2\x80\x99s not far off the mark. And there are more to come.',
#   'source': 'The New York Times',
#   'type': 'News',
#   'url': 'https://www.nytimes.com/2018/06/24/us/politics/obama-white-house-memoirs.html',
#   'word_count': 1341,
#   'locations': [],
#   'subjects': ['Books and Literature',
#    'Writing and Writers',
#    'Presidents and Presidency (US)',
#    'United States Politics and Government',
#    'Book Trade and Publishing']},
#  {'id': '5b95aaa100a1bc2872e8781e',
#   'headline': b'Trump Claims Credit for the Economy. Not So Fast, Says Obama.',
#   'desk': 'Washington',
#   'date': '2018-09-09',
#   'section': 'Politics',
#   'snippet': b'At stake is more than bragging rights: The expansion is central to President Barack Obama\xe2\x80\x99s legacy, and to President Trump\xe2\x80\x99s political standing.',
#   'source': 'The New York Times',
#   'type': 'News',
#   'url': 'https://www.nytimes.com/2018/09/09/us/politics/trump-obama-economy.html',
#   'word_count': 1382,
#   'locations': [],
#   'subjects': ['United States Economy',
#    'Presidents and Presidency (US)',
#    'United States Politics and Government',
#    'Tax Cuts and Jobs Act (2017)',
#    'Labor and Jobs',
#    'Consumer Confidence (Economic Indicator)']},
#  {'id': '5b74093f00a1bc2872e8182b',
#   'headline': b'Hungary\xe2\x80\x99s Leader Was Shunned by Obama, but Has a Friend in Trump',
#   'desk': 'Foreign',
#   'date': '2018-08-15',
#   'section': 'Europe',
#   'snippet': b'Prime Minister Viktor Orban joins a growing roster of right-wing or euroskeptic leaders in Europe to have secured President Trump\xe2\x80\x99s backing.',
#   'source': 'The New York Times',
#   'type': 'News',
#   'url': 'https://www.nytimes.com/2018/08/15/world/europe/hungary-us-orban-trump.html',
#   'word_count': 1515,
#   'locations': ['Hungary'],
#   'subjects': ['United States International Relations',
#    'United States Politics and Government',
#    'News and News Media',
#    'Freedom of the Press',
#    'Lobbying and Lobbyists',
#    'Human Rights and Human Rights Violations']},
#  {'id': '5aa3e4e547de81a90120cc07',
#   'headline': b'For Starters, Snoop Dogg and Neil Gorsuch',
#   'desk': 'Society',
#   'date': '2018-03-10',
#   'section': 'Weddings',
#   'snippet': b'The couple\xe2\x80\x99s contrasting political leanings allowed for healthy debate on their way to marriage.',
#   'source': 'The New York Times',
#   'type': 'News',
#   'url': 'https://www.nytimes.com/2018/03/10/fashion/weddings/for-starters-snoop-dogg-and-neil-gorsuch.html',
#   'word_count': 642,
#   'locations': [],
#   'subjects': ['Weddings and Engagements']},
#  {'id': '5a94ac09410cf7000162e1b8',
#   'headline': b'Labor Board\xe2\x80\x99s Do-Over Leaves an Obama-Era Rule Intact',
#   'desk': 'Business',
#   'date': '2018-02-27',
#   'section': 'Economy',
#   'snippet': b'Citing a member\xe2\x80\x99s conflict in an earlier vote, the panel restored a standard making it easier to hold a company to account for franchisees\xe2\x80\x99 practices.',
#   'source': 'The New York Times',
#   'type': 'News',
#   'url': 'https://www.nytimes.com/2018/02/26/business/economy/labor-board.html',
#   'word_count': 846,
#   'locations': [],
#   'subjects': ['Organized Labor',
#    'Franchises',
#    'Conflicts of Interest',
#    'Regulation and Deregulation of Industry',
#    'Law and Legislation']},
#  {'id': '5a4bf37b95d0e0246f21eeec',
#   'headline': b'Trump Reiterates Support for Iranian Protesters, but Also Criticizes Obama',
#   'desk': 'Washington',
#   'date': '2018-01-02',
#   'section': 'Politics',
#   'snippet': b'Unlike President Barack Obama, who was faulted for his response to the protests that became known as the Green Movement, President Trump has come down on the side of the demonstrators',
#   'source': 'The New York Times',
#   'type': 'News',
#   'url': 'https://www.nytimes.com/2018/01/02/us/politics/trump-iran-protesters.html',
#   'word_count': 1253,
#   'locations': ['Iran'],
#   'subjects': ['United States International Relations',
#    'Demonstrations, Protests and Riots',
#    'Embargoes and Sanctions']},
#  {'id': '5a81e784d4211f00015c07df',
#   'headline': b'Russia, the Obamas, Donald Trump: Your Tuesday Briefing',
#   'desk': 'NYTNow',
#   'date': '2018-02-12',
#   'snippet': b'Here\xe2\x80\x99s what you need to know to start your day.',
#   'source': 'The New York Times',
#   'type': 'briefing',
#   'url': 'https://www.nytimes.com/2018/02/12/briefing/russia-the-obamas-donald-trump.html',
#   'word_count': 1247,
#   'locations': [],
#   'subjects': []},
#  {'id': '5bbfa45000a1bc2872e8e18e',
#   'headline': b'Markets Just Dived. Democrats Shouldn\xe2\x80\x99t Get Too Excited.',
#   'desk': 'Business',
#   'date': '2018-10-11',
#   'snippet': b'The conventional wisdom is that a strong economy and stock markets help the incumbent party in midterm elections. Research doesn\xe2\x80\x99t bear that out.',
#   'source': 'The New York Times',
#   'type': 'News',
#   'url': 'https://www.nytimes.com/2018/10/11/business/markets-midterm-elections.html',
#   'word_count': 924,
#   'locations': [],
#   'subjects': ['Midterm Elections (2018)',
#    'United States Economy',
#    "Standard & Poor's 500-Stock Index",
#    'Stocks and Bonds']},
#  {'id': '5b0fc42247de81a90122b1b0',
#   'headline': b'Trump Against the Liberal Tide',
#   'desk': 'OpEd',
#   'date': '2018-05-31',
#   'snippet': b'The president is pushing ever more aggressively to bring America\xe2\x80\x99s emancipation project to a halt, but it won\xe2\x80\x99t be easy.',
#   'source': 'The New York Times',
#   'type': 'Op-Ed',
#   'url': 'https://www.nytimes.com/2018/05/31/opinion/trump-liberals-emancipation-future.html',
#   'word_count': 2077,
#   'locations': [],
#   'subjects': ['United States Politics and Government',
#    'Immigration and Emigration',
#    'Race and Ethnicity',
#    'Polls and Public Opinion']}]

# %%
def parse_articles(articles):
    '''
    This function takes in a response to the NYT api and parses
    the articles into a list of dictionaries
    '''
    news = []
    for i in articles['response']['docs']:
        dic = {}
        dic['id'] = i['_id']
        if 'abstract' in i:
            dic['abstract'] = i['abstract'].encode("utf8")
        dic['headline'] = i['headline']['main'].encode("utf8")
        dic['desk'] = i['news_desk']
        dic['date'] = i['pub_date'][0:10] # cutting time of day.
        if 'section_name' in i:
            dic['section'] = i['section_name']
        if 'snippet' in i:
            dic['snippet'] = i['snippet'].encode("utf8")
        dic['source'] = i['source']
        dic['type'] = i['type_of_material']
        dic['url'] = i['web_url']
        dic['word_count'] = i['word_count']
        # locations
        locations = []
        for x in range(0,len(i['keywords'])):
            if 'glocations' in i['keywords'][x]['name']:
                locations.append(i['keywords'][x]['value'])
        dic['locations'] = locations
        # subject
        subjects = []
        for x in range(0,len(i['keywords'])):
            if 'subject' in i['keywords'][x]['name']:
                subjects.append(i['keywords'][x]['value'])
        dic['subjects'] = subjects   
        news.append(dic)
    return(news)

# %%
import requests
r = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trump+women+accuse&begin_date=20161001&api-key=6a6c043c723548a98eafc5b624317cac")
data = r.json()
#print(data)
print(len(data["response"]["docs"]))

articles = api.search(q="trump+women+accuse", begin_date=20161001)
print(articles)
print(len(articles['response']['docs']))
# Out:
# 10
# {'status': 'OK', 'copyright': 'Copyright (c) 2018 The New York Times Company. All Rights Reserved.', 'response': {'docs': [], 'meta': {'hits': 0, 'offset': 0, 'time': 16}}}
# 0

# %%
# !/usr/bin/env python
# -*- coding: UTF-8  -*-
# Scraping New York Times using python
# 20120421@ Canberra
# chengjun wang

import json
import urllib.request

'''
About the api and the key, see the links above.
'''

'''step 1: input query information'''
apiUrl='http://api.nytimes.com/svc/search/v1/article?format=json'
query='query=occupy+wall+street'                            # set the query word here
apiDate='begin_date=20110901&end_date=20120214'             # set the date here
fields='fields=body%2Curl%2Ctitle%2Cdate%2Cdes_facet%2Cdesk_facet%2Cbyline'
offset='offset=0'
key='api-key=6a6c043c723548a98eafc5b624317cac'  # input your key here

'''step 2: get the number of offset/pages'''
link=[apiUrl, query, apiDate, fields, offset, key]
ReqUrl='&'.join(link)
jstr = urllib.request.urlopen(ReqUrl).read()  # t = jstr.strip('()')
ts = json.loads( jstr )
number=ts['total'] #  the number of queries  # query=ts['tokens'] # result=ts['results']
print(number)
seq=range(number/9)  # this is not a good way
print(seq)

'''step 3: crawl the data and dump into csv'''
import csv
addressForSavingData= "D:/Research/Dropbox/tweets/wapor_assessing online opinion/News coverage of ows/nyt.csv"
file = open(addressForSavingData,'wb') # save to csv file
for i in seq:
    nums=str(i)
    offsets=''.join(['offset=', nums]) # I made error here, and print is a good way to test
    links=[apiUrl, query, apiDate, fields, offsets, key]
    ReqUrls='&'.join(links)
    print("*_____________*", ReqUrls)
    jstrs = urllib.request.urlopen(ReqUrls).read()
    t = jstrs.strip('()')
    tss= json.loads( t )  # error no joson object
    result = tss['results']
    for ob in result:
        title=ob['title']  # body=ob['body']   # body,url,title,date,des_facet,desk_facet,byline
        print(title)
        url=ob['url']
        date=ob['date'] # desk_facet=ob['desk_facet']  # byline=ob['byline'] # some author names don't exist
        w = csv.writer(file,delimiter=',',quotechar='|', quoting=csv.QUOTE_MINIMAL)
        w.writerow((date, title, url)) # write it out
file.close()
pass
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-78-4c0d698784a5> in <module>()
#      23 link=[apiUrl, query, apiDate, fields, offset, key]
#      24 ReqUrl='&'.join(link)
# ---> 25 jstr = urllib.request.urlopen(ReqUrl).read()  # t = jstr.strip('()')
#      26 ts = json.loads( jstr )
#      27 number=ts['total'] #  the number of queries  # query=ts['tokens'] # result=ts['results']
#
# /anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /anaconda3/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /anaconda3/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# /anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /anaconda3/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found
